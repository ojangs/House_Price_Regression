# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

# %%
pd.set_option('display.max_Columns',None)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# **IMPORT DATSET**

# %%
df= pd.read_csv('house_price_regression_dataset.csv')
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981      0.60
# 1              4272             3              3        2016      4.75
# 2              3592             1              2        2016      3.63
# 3               966             1              2        1977      2.73
# 4              4926             2              1        1993      4.70
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978      2.17
# 996            3179             1              2        1999      2.98
# 997            2606             4              2        1962      4.06
# 998            4723             5              2        1950      1.93
# 999            3268             4              2        1983      3.11
#
#      Garage_Size  Neighborhood_Quality  House_Price
# 0              0                     5   262,382.85
# 1              1                     6   985,260.85
# 2              0                     9   777,977.39
# 3              1                     8   229,698.92
# 4              0                     8 1,041,740.86
# ..           ...                   ...          ...
# 995            2                    10   701,494.00
# 996            1                    10   683,723.16
# 997            0                     2   572,024.02
# 998            0                     7   964,865.30
# 999            2                     2   742,599.25
#
# [1000 rows x 8 columns]

# %%
df.shape
# Out:
# (1000, 8)

# %%
#pengecekan tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
#pengecekan nilai kosong
df.isna().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# count        1,000.00      1,000.00       1,000.00    1,000.00  1,000.00
# mean         2,815.42          2.99           1.97    1,986.55      2.78
# std          1,255.51          1.43           0.82       20.63      1.30
# min            503.00          1.00           1.00    1,950.00      0.51
# 25%          1,749.50          2.00           1.00    1,969.00      1.67
# 50%          2,862.50          3.00           2.00    1,986.00      2.81
# 75%          3,849.50          4.00           3.00    2,004.25      3.92
# max          4,999.00          5.00           3.00    2,022.00      4.99
#
#        Garage_Size  Neighborhood_Quality  House_Price
# count     1,000.00              1,000.00     1,000.00
# mean          1.02                  5.62   618,861.02
# std           0.81                  2.89   253,568.06
# min           0.00                  1.00   111,626.85
# 25%           0.00                  3.00   401,648.23
# 50%           1.00                  6.00   628,267.29
# 75%           2.00                  8.00   827,141.28
# max           2.00                 10.00 1,108,236.84

# %%
df.corr(method='pearson')
# Out:
#                       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  \
# Square_Footage                  1.00         -0.04          -0.03       -0.02
# Num_Bedrooms                   -0.04          1.00           0.02       -0.02
# Num_Bathrooms                  -0.03          0.02           1.00       -0.02
# Year_Built                     -0.02         -0.02          -0.02        1.00
# Lot_Size                        0.09         -0.01           0.03       -0.06
# Garage_Size                     0.03          0.11           0.02       -0.03
# Neighborhood_Quality           -0.01         -0.05           0.02       -0.01
# House_Price                     0.99          0.01          -0.00        0.05
#
#                       Lot_Size  Garage_Size  Neighborhood_Quality  House_Price
# Square_Footage            0.09         0.03                 -0.01         0.99
# Num_Bedrooms             -0.01         0.11                 -0.05         0.01
# Num_Bathrooms             0.03         0.02                  0.02        -0.00
# Year_Built               -0.06        -0.03                 -0.01         0.05
# Lot_Size                  1.00         0.00                  0.04         0.16
# Garage_Size               0.00         1.00                 -0.01         0.05
# Neighborhood_Quality      0.04        -0.01                  1.00        -0.01
# House_Price               0.16         0.05                 -0.01         1.00

# %% [markdown]
# **DATA SPLITTING**

# %%
X = df.drop(columns=['House_Price'])
y = df.House_Price
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle=True, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 7), (200, 7), (800,), (200,))

# %% [markdown]
# **PREDIKSI HARGA RUMAH MENGGUNAKAN LINEAR REGRESSI**

# %%
from sklearn.linear_model import LinearRegression

# %%
#TRAINING, VALIDATING, TESTING
model = GridSearchCV(LinearRegression(),param_grid={}, cv=3, n_jobs=-1, verbose=1)
model.fit(X_train,y_train)
model.score(X_train, y_train),model.score(X_test, y_test),model.best_score_
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# (0.9985375946918145, 0.9984263636823408, np.float64(0.9984954474304325))

# %% [markdown]
# **EVALUASI MODEL MENGGUNAKAN R2**

# %%
from sklearn.metrics import r2_score

# %%
y_pred = model.predict(X_test)
R2 = r2_score(y_test, y_pred)
print(R2)
# Out:
# 0.9984263636823408

# %% [markdown]
# **PREDIKSI DATA BARU**

# %%
prediksi = {
    'Square_Footage': [1800, 2500, 3200, 1500, 4000, 2750, 2200, 3100, 2000, 3600],  # Luas rumah dalam sqft
    'Num_Bedrooms': [3, 4, 5, 2, 6, 4, 3, 5, 3, 5],  # Jumlah kamar tidur
    'Num_Bathrooms': [2, 3, 4, 1, 5, 3, 2, 4, 2, 4],  # Jumlah kamar mandi
    'Year_Built': [2005, 2010, 2018, 1995, 2022, 2015, 2008, 2020, 2012, 2019],  # Tahun dibangun
    'Lot_Size': [4000, 5000, 6000, 3000, 7000, 5500, 4500, 6200, 4800, 6800],  # Luas tanah dalam sqft
    'Garage_Size': [1, 2, 2, 1, 3, 2, 1, 2, 1, 3],  # Kapasitas garasi
    'Neighborhood_Quality': [7, 8, 9, 6, 10, 8, 7, 9, 7, 9]  # Kualitas lingkungan (misalnya skala 1-10)
}

# Ubah ke DataFrame
X_pred = pd.DataFrame(prediksi)

# %%
y_pred_ = model.predict(X_pred)

# %%
X_pred['Predicted_Price'] = y_pred_

# %%
X_pred
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1800             3              2        2005      4000
# 1            2500             4              3        2010      5000
# 2            3200             5              4        2018      6000
# 3            1500             2              1        1995      3000
# 4            4000             6              5        2022      7000
# 5            2750             4              3        2015      5500
# 6            2200             3              2        2008      4500
# 7            3100             5              4        2020      6200
# 8            2000             3              2        2012      4800
# 9            3600             5              4        2019      6800
#
#    Garage_Size  Neighborhood_Quality  Predicted_Price
# 0            1                     7    59,935,180.22
# 1            2                     8    74,988,886.45
# 2            2                     9    90,040,427.14
# 3            1                     6    44,961,457.75
# 4            3                    10   105,113,091.15
# 5            2                     8    82,486,424.65
# 6            1                     7    67,460,658.34
# 7            2                     9    92,999,539.77
# 8            1                     7    71,890,345.16
# 9            3                     9   102,034,679.65
